# %%
# !pip install findspark

# %%
import findspark

# %%
findspark.init("C:\spark")

# %%
from pyspark import SparkContext

# %% [markdown]
# ## MAKİNE ÖĞRENMESİ

# %% [markdown]
# ## 1.1. BÜYÜK VERİDE VERİ ÖN İŞLEME

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("vahit_hoca_makine_ogrenmesi") \
    .getOrCreate()

# %%
spark_df = spark.read.csv("./churn.csv", header=True, inferSchema=True)

# %%
spark_df.show(5)
# Out:
# +---+----------------+----+--------------+---------------+-----+---------+-----+
# |_c0|           Names| Age|Total_Purchase|Account_Manager|Years|Num_Sites|Churn|
# +---+----------------+----+--------------+---------------+-----+---------+-----+
# |  0|Cameron Williams|42.0|       11066.8|              0| 7.22|      8.0|    1|
# |  1|   Kevin Mueller|41.0|      11916.22|              0|  6.5|     11.0|    1|
# |  2|     Eric Lozano|38.0|      12884.75|              0| 6.67|     12.0|    1|
# |  3|   Phillip White|42.0|       8010.76|              0| 6.71|     10.0|    1|
# |  4|  Cynthia Norton|37.0|       9191.58|              0| 5.56|      9.0|    1|
# +---+----------------+----+--------------+---------------+-----+---------+-----+
# only showing top 5 rows

# %%
spark_df = spark_df.toDF(*[c.lower() for c in spark_df.columns])

# %%
spark_df.show(5)
# Out:
# +-----+----------------+----+--------------+---------------+-----+---------+-----+
# |index|           names| age|total_purchase|account_manager|years|num_sites|churn|
# +-----+----------------+----+--------------+---------------+-----+---------+-----+
# |    0|Cameron Williams|42.0|       11066.8|              0| 7.22|      8.0|    1|
# |    1|   Kevin Mueller|41.0|      11916.22|              0|  6.5|     11.0|    1|
# |    2|     Eric Lozano|38.0|      12884.75|              0| 6.67|     12.0|    1|
# |    3|   Phillip White|42.0|       8010.76|              0| 6.71|     10.0|    1|
# |    4|  Cynthia Norton|37.0|       9191.58|              0| 5.56|      9.0|    1|
# +-----+----------------+----+--------------+---------------+-----+---------+-----+
# only showing top 5 rows

# %%
spark_df = spark_df.withColumnRenamed("_c0", "index")

# %%
spark_df.show(5)
# Out:
# +-----+----------------+----+--------------+---------------+-----+---------+-----+
# |index|           names| age|total_purchase|account_manager|years|num_sites|churn|
# +-----+----------------+----+--------------+---------------+-----+---------+-----+
# |    0|Cameron Williams|42.0|       11066.8|              0| 7.22|      8.0|    1|
# |    1|   Kevin Mueller|41.0|      11916.22|              0|  6.5|     11.0|    1|
# |    2|     Eric Lozano|38.0|      12884.75|              0| 6.67|     12.0|    1|
# |    3|   Phillip White|42.0|       8010.76|              0| 6.71|     10.0|    1|
# |    4|  Cynthia Norton|37.0|       9191.58|              0| 5.56|      9.0|    1|
# +-----+----------------+----+--------------+---------------+-----+---------+-----+
# only showing top 5 rows

# %%
spark_df.count()
# Out:
# 900

# %%
len(spark_df.columns)
# Out:
# 8

# %%
spark_df.columns
# Out:
# ['index',
#  'names',
#  'age',
#  'total_purchase',
#  'account_manager',
#  'years',
#  'num_sites',
#  'churn']

# %%
spark_df.describe().show()
# Out:
# +-------+------------------+-------------+-----------------+-----------------+------------------+-----------------+------------------+-------------------+
# |summary|             index|        names|              age|   total_purchase|   account_manager|            years|         num_sites|              churn|
# +-------+------------------+-------------+-----------------+-----------------+------------------+-----------------+------------------+-------------------+
# |  count|               900|          900|              900|              900|               900|              900|               900|                900|
# |   mean|             449.5|         NULL|41.81666666666667|10062.82403333334|0.4811111111111111| 5.27315555555555| 8.587777777777777|0.16666666666666666|
# | stddev|259.95191863111916|         NULL|6.127560416916251|2408.644531858096|0.4999208935073339|1.274449013194616|1.7648355920350969| 0.3728852122772358|
# ...

# %%
spark_df.select("age","total_purchase","account_manager","years","num_sites","churn").describe().toPandas().transpose()
# Out:
#                      0                    1                   2      3  \
# summary          count                 mean              stddev    min
# age                900    41.81666666666667   6.127560416916251   22.0
# total_purchase     900    10062.82403333334   2408.644531858096  100.0
# account_manager    900   0.4811111111111111  0.4999208935073339      0
# years              900     5.27315555555555   1.274449013194616    1.0
# num_sites          900    8.587777777777777  1.7648355920350969    3.0
# churn              900  0.16666666666666666  0.3728852122772358      0
#
#                         4
# summary               max
# age                  65.0
# total_purchase   18026.01
# account_manager         1
# years                9.15
# num_sites            14.0
# churn                   1

# %%
spark_df = spark_df.dropna()

# %%
spark_df = spark_df.withColumn("age_kare", spark_df.age**2)

# %%
spark_df.show(3)
# Out:
# +-----+----------------+----+--------------+---------------+-----+---------+-----+--------+
# |index|           names| age|total_purchase|account_manager|years|num_sites|churn|age_kare|
# +-----+----------------+----+--------------+---------------+-----+---------+-----+--------+
# |    0|Cameron Williams|42.0|       11066.8|              0| 7.22|      8.0|    1|  1764.0|
# |    1|   Kevin Mueller|41.0|      11916.22|              0|  6.5|     11.0|    1|  1681.0|
# |    2|     Eric Lozano|38.0|      12884.75|              0| 6.67|     12.0|    1|  1444.0|
# +-----+----------------+----+--------------+---------------+-----+---------+-----+--------+
# only showing top 3 rows

# %%
##bagimli değişkeni belirtme

# %%
from pyspark.ml.feature import StringIndexer

# %%
stringIndexer = StringIndexer(inputCol="churn", outputCol= "label")
mod = stringIndexer.fit(spark_df)
indexed = mod.transform(spark_df)
spark_df = indexed.withColumn("label", indexed["label"].cast("integer"))

# %%
spark_df.show(3)
# Out:
# +-----+----------------+----+--------------+---------------+-----+---------+-----+--------+-----+
# |index|           names| age|total_purchase|account_manager|years|num_sites|churn|age_kare|label|
# +-----+----------------+----+--------------+---------------+-----+---------+-----+--------+-----+
# |    0|Cameron Williams|42.0|       11066.8|              0| 7.22|      8.0|    1|  1764.0|    1|
# |    1|   Kevin Mueller|41.0|      11916.22|              0|  6.5|     11.0|    1|  1681.0|    1|
# |    2|     Eric Lozano|38.0|      12884.75|              0| 6.67|     12.0|    1|  1444.0|    1|
# +-----+----------------+----+--------------+---------------+-----+---------+-----+--------+-----+
# only showing top 3 rows

# %%
## bagimsiz degiskenlerin ayarlanmasi

# %%
from pyspark.ml.feature import VectorAssembler

# %%
spark_df.columns
# Out:
# ['index',
#  'names',
#  'age',
#  'total_purchase',
#  'account_manager',
#  'years',
#  'num_sites',
#  'churn',
#  'age_kare',
#  'label']

# %%
bagimsiz_degiskenler = ["age","total_purchase","account_manager","years","num_sites"]

# %%
vectorAssembler = VectorAssembler(inputCols = bagimsiz_degiskenler, outputCol="features")
va_df = vectorAssembler.transform(spark_df)

# %%
va_df.show(3)
# Out:
# +-----+----------------+----+--------------+---------------+-----+---------+-----+--------+-----+--------------------+
# |index|           names| age|total_purchase|account_manager|years|num_sites|churn|age_kare|label|            features|
# +-----+----------------+----+--------------+---------------+-----+---------+-----+--------+-----+--------------------+
# |    0|Cameron Williams|42.0|       11066.8|              0| 7.22|      8.0|    1|  1764.0|    1|[42.0,11066.8,0.0...|
# |    1|   Kevin Mueller|41.0|      11916.22|              0|  6.5|     11.0|    1|  1681.0|    1|[41.0,11916.22,0....|
# |    2|     Eric Lozano|38.0|      12884.75|              0| 6.67|     12.0|    1|  1444.0|    1|[38.0,12884.75,0....|
# +-----+----------------+----+--------------+---------------+-----+---------+-----+--------+-----+--------------------+
# only showing top 3 rows

# %%
final_df = va_df.select(["features","label"])

# %%
final_df.show(3)
# Out:
# +--------------------+-----+
# |            features|label|
# +--------------------+-----+
# |[42.0,11066.8,0.0...|    1|
# |[41.0,11916.22,0....|    1|
# |[38.0,12884.75,0....|    1|
# +--------------------+-----+
# only showing top 3 rows

# %%
## test-train seti

# %%
splits = final_df.randomSplit([0.70,0.30])
train_df = splits[0]
test_df = splits[1]

# %%
train_df
# Out:
# DataFrame[features: vector, label: int]

# %%
test_df
# Out:
# DataFrame[features: vector, label: int]

# %% [markdown]
# ## 1.2. BÜYÜK VERİDE GBM İLE MÜŞTERİ TERK MODELLEMESİ

# %%
from pyspark.ml.classification import GBTClassifier

# %%
gbm = GBTClassifier(maxIter = 10, featuresCol ="features", labelCol="label")

# %%
gbm_model = gbm.fit(train_df)

# %%
spark.sparkContext
# Out:
# <SparkContext master=local[*] appName=vahit_hoca_makine_ogrenmesi>

# %%
y_pred = gbm_model.transform(test_df)

# %%
y_pred
# Out:
# DataFrame[features: vector, label: int, rawPrediction: vector, probability: vector, prediction: double]

# %%
ac = y_pred.select("label","prediction")

# %%
ac.filter(ac.label == ac.prediction).count()/ac.count()
# Out:
# 0.8971631205673759

# %% [markdown]
# ## Model Tunıng

# %%
from pyspark.ml.evaluation import BinaryClassificationEvaluator
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator

evaluator = BinaryClassificationEvaluator()

paramGrid = (ParamGridBuilder()
             .addGrid(gbm.maxDepth, [2, 4, 6])
             .addGrid(gbm.maxBins, [20, 30])
             .addGrid(gbm.maxIter, [10, 20])
             .build())

cv = CrossValidator(estimator=gbm, estimatorParamMaps=paramGrid, evaluator=evaluator, numFolds=10)

# %%
cvModel = cv.fit(train_df)

# %%
y_pred = cvModel.transform(test_df)

# %%
ac = y_pred.select("label","prediction")

# %%
ac.filter(ac.label == ac.prediction).count() / ac.count()
# Out:
# 0.8971631205673759

# %% [markdown]
# ## yeni müşteri terk eder mi etmez mi ?

# %%
import pandas as pd

names = pd.Series(["Ali Ahmetoğlu", "Taner Gün", "Berkay", "Polat Konak", "Kamil Atasoy"])
age = pd.Series([38, 43, 34, 50, 40])
total_purchase = pd.Series([30000, 10000, 6000, 30000, 100000])
account_manager = pd.Series([1, 0, 0, 1, 1])
years = pd.Series([20, 10, 3, 8, 30])
num_sites = pd.Series([30, 8, 8, 6, 50])

yeni_musteriler = pd.DataFrame({
    'names': names,
    'age': age,
    'total_purchase': total_purchase,
    'account_manager': account_manager,
    'years': years,
    'num_sites': num_sites})

yeni_musteriler.columns
# Out:
# Index(['names', 'age', 'total_purchase', 'account_manager', 'years',
#        'num_sites'],
#       dtype='object')

# %%
yeni_sdf = spark.createDataFrame(yeni_musteriler)

# %%
yeni_sdf.show()
# Out:
# +-------------+---+--------------+---------------+-----+---------+
# |        names|age|total_purchase|account_manager|years|num_sites|
# +-------------+---+--------------+---------------+-----+---------+
# |Ali Ahmetoğlu| 38|         30000|              1|   20|       30|
# |    Taner Gün| 43|         10000|              0|   10|        8|
# |       Berkay| 34|          6000|              0|    3|        8|
# |  Polat Konak| 50|         30000|              1|    8|        6|
# | Kamil Atasoy| 40|        100000|              1|   30|       50|
# +-------------+---+--------------+---------------+-----+---------+

# %%
yeni_musteriler = vectorAssembler.transform(yeni_sdf)

# %%
results = cvModel.transform(yeni_musteriler)

# %%
results.select("names","prediction").show()
# Out:
# +-------------+----------+
# |        names|prediction|
# +-------------+----------+
# |Ali Ahmetoğlu|       1.0|
# |    Taner Gün|       0.0|
# |       Berkay|       0.0|
# |  Polat Konak|       0.0|
# | Kamil Atasoy|       1.0|
# +-------------+----------+

# %% [markdown]
# ## 2. BÜYÜK VERİ MANİPÜLASYONU ve GÖRSELLEŞTİRİLMESİ

# %% [markdown]
# ### Spark Uygulamasının Başlatılması

# %%
import pyspark
from pyspark.sql import SparkSession
from pyspark.conf import SparkConf

# %%
spark = SparkSession.builder \
    .master("local") \
    .appName("pyspark_giris") \
    .getOrCreate()

sc = spark.sparkContext

# %%
sc
# Out:
# <SparkContext master=local[*] appName=vahit_hoca_makine_ogrenmesi>

# %%
sc.version
# Out:
# '3.5.9'

# %%
sc.appName
# Out:
# 'vahit_hoca_makine_ogrenmesi'

# %% [markdown]
# ## 2.1. TEMEL DATAFRAME İŞLEMLERİ

# %%
spark_df = spark.read.csv("./churn.csv", header= True, inferSchema = True)

# %%
spark_df.printSchema()
# Out:
# root
#  |-- _c0: integer (nullable = true)
#  |-- Names: string (nullable = true)
#  |-- Age: double (nullable = true)
#  |-- Total_Purchase: double (nullable = true)
#  |-- Account_Manager: integer (nullable = true)
#  |-- Years: double (nullable = true)
#  |-- Num_Sites: double (nullable = true)
#  |-- Churn: integer (nullable = true)

# %%
type(spark_df)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
spark_df.cache()
# Out:
# DataFrame[_c0: int, Names: string, Age: double, Total_Purchase: double, Account_Manager: int, Years: double, Num_Sites: double, Churn: int]

# %%
import seaborn as sns
df = sns.load_dataset("diamonds")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
spark_df.head()
# Out:
# Row(_c0=0, Names='Cameron Williams', Age=42.0, Total_Purchase=11066.8, Account_Manager=0, Years=7.22, Num_Sites=8.0, Churn=1)

# %%
df.dtypes
# Out:
# carat       float64
# cut        category
# color      category
# clarity    category
# depth       float64
# table       float64
# price         int64
# x           float64
# y           float64
# z           float64
# dtype: object

# %%
spark_df.dtypes
# Out:
# [('_c0', 'int'),
#  ('Names', 'string'),
#  ('Age', 'double'),
#  ('Total_Purchase', 'double'),
#  ('Account_Manager', 'int'),
#  ('Years', 'double'),
#  ('Num_Sites', 'double'),
#  ('Churn', 'int')]

# %%
df.ndim
# Out:
# 2

# %%
spark_df.ndim
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 spark_df.ndim
#
# File C:\spark\python\pyspark\sql\dataframe.py:3128, in DataFrame.__getattr__(self, name)
#    3095 """Returns the :class:`Column` denoted by ``name``.
#    3096
#    3097 .. versionadded:: 1.3.0
#    (...)   3125 +---+
#    3126 """
#    3127 if name not in self.columns:
# -> 3128     raise AttributeError(
#    3129         "'%s' object has no attribute '%s'" % (self.__class__.__name__, name)
#    3130     )
#    3131 jc = self._jdf.apply(name)
#    3132 return Column(jc)
#
# AttributeError: 'DataFrame' object has no attribute 'ndim'

# %%
spark_df.show(2, truncate=True)
# Out:
# +---+----------------+----+--------------+---------------+-----+---------+-----+
# |_c0|           Names| Age|Total_Purchase|Account_Manager|Years|Num_Sites|Churn|
# +---+----------------+----+--------------+---------------+-----+---------+-----+
# |  0|Cameron Williams|42.0|       11066.8|              0| 7.22|      8.0|    1|
# |  1|   Kevin Mueller|41.0|      11916.22|              0|  6.5|     11.0|    1|
# +---+----------------+----+--------------+---------------+-----+---------+-----+
# only showing top 2 rows

# %%
spark_df.count()
# Out:
# 900

# %%
spark_df.columns
# Out:
# ['_c0',
#  'Names',
#  'Age',
#  'Total_Purchase',
#  'Account_Manager',
#  'Years',
#  'Num_Sites',
#  'Churn']

# %%
spark_df.describe()
# Out:
# DataFrame[summary: string, _c0: string, Names: string, Age: string, Total_Purchase: string, Account_Manager: string, Years: string, Num_Sites: string, Churn: string]

# %%
spark_df.describe().show()
# Out:
# +-------+------------------+-------------+-----------------+-----------------+------------------+-----------------+------------------+-------------------+
# |summary|               _c0|        Names|              Age|   Total_Purchase|   Account_Manager|            Years|         Num_Sites|              Churn|
# +-------+------------------+-------------+-----------------+-----------------+------------------+-----------------+------------------+-------------------+
# |  count|               900|          900|              900|              900|               900|              900|               900|                900|
# |   mean|             449.5|         NULL|41.81666666666667|10062.82403333334|0.4811111111111111| 5.27315555555555| 8.587777777777777|0.16666666666666666|
# | stddev|259.95191863111916|         NULL|6.127560416916251|2408.644531858096|0.4999208935073339|1.274449013194616|1.7648355920350969| 0.3728852122772358|
# ...

# %%
spark_df.describe("Age").show()
# Out:
# +-------+-----------------+
# |summary|              Age|
# +-------+-----------------+
# |  count|              900|
# |   mean|41.81666666666667|
# | stddev|6.127560416916251|
# |    min|             22.0|
# |    max|             65.0|
# +-------+-----------------+

# %%
spark_df.select("Age","Names").show()
# Out:
# +----+-------------------+
# | Age|              Names|
# +----+-------------------+
# |42.0|   Cameron Williams|
# |41.0|      Kevin Mueller|
# |38.0|        Eric Lozano|
# |42.0|      Phillip White|
# |37.0|     Cynthia Norton|
# |48.0|   Jessica Williams|
# |44.0|        Eric Butler|
# |32.0|      Zachary Walsh|
# |43.0|        Ashlee Carr|
# |40.0|     Jennifer Lynch|
# |30.0|       Paula Harris|
# |45.0|     Bruce Phillips|
# |45.0|       Craig Garner|
# |40.0|       Nicole Olson|
# |41.0|     Harold Griffin|
# |38.0|       James Wright|
# |45.0|      Doris Wilkins|
# |43.0|Katherine Carpenter|
# |53.0|     Lindsay Martin|
# |46.0|        Kathy Curry|
# +----+-------------------+
# only showing top 20 rows

# %%
spark_df.filter(spark_df.Age > 40).count()
# Out:
# 524

# %%
spark_df.groupby("Churn").count().show()
# Out:
# +-----+-----+
# |Churn|count|
# +-----+-----+
# |    1|  150|
# |    0|  750|
# +-----+-----+

# %%
spark_df.groupby("Churn").agg({"Age":"mean"}).show()
# Out:
# +-----+-----------------+
# |Churn|         avg(Age)|
# +-----+-----------------+
# |    1|42.99333333333333|
# |    0|41.58133333333333|
# +-----+-----------------+

# %% [markdown]
# ## 2.2. SQL İŞLEMLERİ

# %%
spark_df.createOrReplaceTempView("tbl_df")

# %%
# Eski kilitlenen oturumu güvenle kapatıyoruz
spark.stop()

# Yenisini sıfırdan başlatıyoruz
from pyspark.sql import SparkSession
spark = SparkSession.builder \
    .master("local[*]") \
    .appName("spark_sql_tam_gaz") \
    .getOrCreate()

# %%
# Eğer elinizde churn veri seti varsa onun yolunu yazın (Örn: "./churn.csv")
spark_df = spark.read.csv("./churn.csv", header=True, inferSchema=True)

# Az önce hata veren geçici SQL tablosunu güncel yöntemle kaydediyoruz
spark_df.createOrReplaceTempView("tbl_df")

# %%
spark.sql("SELECT * FROM tbl_df LIMIT 5").show()
# Out:
# +---+----------------+----+--------------+---------------+-----+---------+-----+
# |_c0|           Names| Age|Total_Purchase|Account_Manager|Years|Num_Sites|Churn|
# +---+----------------+----+--------------+---------------+-----+---------+-----+
# |  0|Cameron Williams|42.0|       11066.8|              0| 7.22|      8.0|    1|
# |  1|   Kevin Mueller|41.0|      11916.22|              0|  6.5|     11.0|    1|
# |  2|     Eric Lozano|38.0|      12884.75|              0| 6.67|     12.0|    1|
# |  3|   Phillip White|42.0|       8010.76|              0| 6.71|     10.0|    1|
# |  4|  Cynthia Norton|37.0|       9191.58|              0| 5.56|      9.0|    1|
# +---+----------------+----+--------------+---------------+-----+---------+-----+

# %%
spark.sql("show tables").show()
# Out:
# +---------+---------+-----------+
# |namespace|tableName|isTemporary|
# +---------+---------+-----------+
# |         |   tbl_df|       true|
# +---------+---------+-----------+

# %%
spark.sql("select Age from tbl_df").show()
# Out:
# +----+
# | Age|
# +----+
# |42.0|
# |41.0|
# |38.0|
# |42.0|
# |37.0|
# |48.0|
# |44.0|
# |32.0|
# |43.0|
# |40.0|
# |30.0|
# |45.0|
# |45.0|
# |40.0|
# |41.0|
# |38.0|
# |45.0|
# |43.0|
# |53.0|
# |46.0|
# +----+
# only showing top 20 rows

# %%
spark.sql("select Age from tbl_df").show(5)
# Out:
# +----+
# | Age|
# +----+
# |42.0|
# |41.0|
# |38.0|
# |42.0|
# |37.0|
# +----+
# only showing top 5 rows

# %%
spark.sql("select Churn, mean(age) from tbl_df group by Churn").show()
# Out:
# +-----+-----------------+
# |Churn|        mean(age)|
# +-----+-----------------+
# |    1|42.99333333333333|
# |    0|41.58133333333333|
# +-----+-----------------+

# %% [markdown]
# ## 2.3. BÜYÜK VERİ GÖRSELLEŞTİRME

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.barplot(x="Churn", y=spark_df.Churn.index, data =spark_df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[134], line 1
# ----> 1 sns.barplot(x="Churn", y=spark_df.Churn.index, data =spark_df)
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2341, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2338 if estimator is len:
#    2339     estimator = "size"
# -> 2341 p = _CategoricalAggPlotter(
#    2342     data=data,
#    2343     variables=dict(x=x, y=y, hue=hue, units=units, weight=weights),
#    2344     order=order,
#    2345     orient=orient,
#    2346     color=color,
#    2347     legend=legend,
#    2348 )
#    2350 if ax is None:
#    2351     ax = plt.gca()
#
# ...

# %%
sdf = spark_df.toPandas()

# %%
sdf
# Out:
#      _c0             Names   Age  Total_Purchase  Account_Manager  Years  \
# 0      0  Cameron Williams  42.0        11066.80                0   7.22
# 1      1     Kevin Mueller  41.0        11916.22                0   6.50
# 2      2       Eric Lozano  38.0        12884.75                0   6.67
# 3      3     Phillip White  42.0         8010.76                0   6.71
# 4      4    Cynthia Norton  37.0         9191.58                0   5.56
# ..   ...               ...   ...             ...              ...    ...
# 895  895       Paul Miller  42.0        12800.82                1   3.62
# 896  896    Natalie Hodges  52.0         9893.92                0   6.91
# 897  897         Ana Smith  45.0        12056.18                0   5.46
# 898  898    Justin Leonard  51.0         6517.93                1   5.47
# 899  899   Joseph Williams  39.0         9315.60                1   5.02
#
#      Num_Sites  Churn
# 0          8.0      1
# 1         11.0      1
# ...

# %%
sns.barplot(x="Churn", y=sdf.Churn.index, data =sdf, hue="Churn", legend=False);

# %%
spark_df.groupby("Churn").count().show()
# Out:
# +-----+-----+
# |Churn|count|
# +-----+-----+
# |    1|  150|
# |    0|  750|
# +-----+-----+

# %%
a = spark_df.groupby("Churn").count().toPandas()

# %%
a
# Out:
#    Churn  count
# 0      1    150
# 1      0    750

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
spark.stop()
